# %% [markdown]
# # Getting Started with NLTK
# - Before beginning we need to install nltk

# %%
#install nltk
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# **Install required NLTK data**
# Once NLTK is installed, install the required nltk by running below cell

# %%
#import and install required libraries
import nltk #import the nltk
import matplotlib.pyplot as plt #import matplotlib package

# %%
# browse the available packages
# nltk.download()

# %% [markdown]
# Select required module you want install, for example **book** in this case.
# If you want to install all module, simply click on Download.

# %% [markdown]
# **Loading Book Module**
# Load some text to explore and perform different experiments

# %%
#import all from module book
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# As we can see nltk book libraries contains 9 text(raw data) which is displayed
#
# If you want to know about the text, then, simply type text name as shown:

# %%
#know text
text1, text2, text3, text4, text5, text6, text7
# Out:
# (<Text: Moby Dick by Herman Melville 1851>,
#  <Text: Sense and Sensibility by Jane Austen 1811>,
#  <Text: The Book of Genesis>,
#  <Text: Inaugural Address Corpus>,
#  <Text: Chat Corpus>,
#  <Text: Monty Python and the Holy Grail>,
#  <Text: Wall Street Journal>)

# %% [markdown]
# Also, let us print first 10 words from the Book _Moby Dick_ i.e. _text1_

# %%
moby_dick_10 = text1[:10]
moby_dick_10
# Out:
# ['[',
#  'Moby',
#  'Dick',
#  'by',
#  'Herman',
#  'Melville',
#  '1851',
#  ']',
#  'ETYMOLOGY',
#  '.']

# %% [markdown]
# # Searching Text

# %% [markdown]
# **concordance**
# - There are many ways to examine the context of text apart from simply reading it.
# - concordance view shows us every occurence of a given word, together with some context.

# %%
#concordance
text1.concordance("monstrous") #occurence of monstrous in text1 with some context
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text2.concordance("monstrous") #occurence of monstrous in text2 with some context
# Out:
# Displaying 11 of 11 matches:
# . " Now , Palmer , you shall see a monstrous pretty girl ." He immediately went
# your sister is to marry him . I am monstrous glad of it , for then I shall have
# ou may tell your sister . She is a monstrous lucky girl to get him , upon my ho
# k how you will like them . Lucy is monstrous pretty , and so good humoured and
#  Jennings , " I am sure I shall be monstrous glad of Miss Marianne ' s company
#  usual noisy cheerfulness , " I am monstrous glad to see you -- sorry I could n
# t however , as it turns out , I am monstrous glad there was never any thing in
# so scornfully ! for they say he is monstrous fond of her , as well he may . I s
# possible that she should ." " I am monstrous glad of it . Good gracious ! I hav
# thing of the kind . So then he was monstrous happy , and talked on some time ab
# e very genteel people . He makes a monstrous deal of money , and they keep thei

# %% [markdown]
# **similar**
# - Helps to list out what other words appear in the similar range of contexts to desired word
# - List the word in according to the best matching context

# %%
#display words with similar context with word "monstous"
print("**displaying list of word from text2 that has similar context with word, monstrous**")
text2.similar("monstrous") #display all matching words

print("\n**Displaying only 4 words**")
text2.similar("monstrous", num=4)
# Out:
# **displaying list of word from text2 that has similar context with word, monstrous**
# very so exceedingly heartily a as good great extremely remarkably
# sweet vast amazingly
#
# **Displaying only 4 words**
# very so exceedingly heartily

# %% [markdown]
# **common_contexts**
# - Allows to examine the contexts that are shared by two or more words
# - list most frequent context first

# %%
#display common context of word, monstrous and very
print("**Diplay common context of word, monstrous and very**")
text2.common_contexts(["monstrous", "very"])

#display only two context of word, monstrous and very
print("\n**Display only 2 two context of word, monstrous and very**")
text2.common_contexts(["monstrous", "very"], num=2)
# Out:
# **Diplay common context of word, monstrous and very**
# a_pretty am_glad a_lucky is_pretty be_glad
#
# **Display only 2 two context of word, monstrous and very**
# a_pretty am_glad

# %% [markdown]
# **dispersion plot**
# - We can determine the location of words in the text i.e. how many words from the begining it appears
# - It looks like a bar code
# - It shows the spread of any particular word accross the whole text.
# - In Dispersion plot x-axis represents the "narrative time"- measured by the number of words in Text.
# - When the desired word appears in the text a blue vertical line is plotted, otherwise it remains blank (white line).
#
#
# References:
# - https://medium.com/@rohanjoseph_91119/dispersion-plot-from-bible-1cf7173074f4

# %%
#dispersion plot

#set figure size
fig = plt.figure(figsize=(12, 6))

#dispersion plot for word citizens, democracy, freedom, duties, america in text4
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"])

#show figure
plt.show()

# %% [markdown]
# Summary of Dispersion Plot:
# - word _citizens_ appears almost every place in the text i.e begining, middle, and end of text
# - word _America_ appears mostly at the end in the text

# %% [markdown]
# # Counting Vocabulary
# - Using computer to count the number of words in a text in a variety of useful ways
#
#
# **1.Find length of text**
# - return length of text from start to finish.
# - Take account into words and punctutation symbols that appear.

# %%
#find length, text3
print(f"Length of **text3** is: {len(text3)}")
# Out:
# Length of **text3** is: 44764

# %% [markdown]
# So, Book "Genesis" i.e. "text3" has 44764 words, punctutation symbols, or "tokens".
# A **Token** is the technical name for sequence of characters --such as hairy, his, or, :)-- that is treated as a group

# %% [markdown]
# **2.Find distinct words in text**
# - How many distinct word does the _book of Genesis_ contain? i.e. _text3_
# - Vocabulary(word) in text is just the set of tokens, as in set there is no duplicate items

# %%
#find distinct word in text3
print("**Set of distinct word are:**")
print(sorted(set(text3))) #sorted list of distinct vocabulary in text3

print(f"\n**Length of distinct word is: {len(set(text3))}**")
# Out:
# **Set of distinct word are:**
# ...

# %% [markdown]
# - We obtained a sorted list of vocabulary items, begining with various punctuation symbols and continuing with words starting with A.
# - All capitalized words precede lowercase words.
# - Distinct list of words is a Vocabulary.
# - Also, we can see that, text3 has total 44,764 total tokens, however it has only 2,789 distinct words

# %% [markdown]
# **3.Calculate a measure of the lexical richness of the text**
# - Lexical richness is about the quality of vocabulary in a language sample.
# - Lexical richness = len(set(text))/len(text)

# %%
#lexical richness for text3
num_distinct_words = len(set(text3))
num_total_words = len(text3)

lexical_richness = num_distinct_words/num_total_words

print(f"Lexical richness of **text3** is {lexical_richness}")
# Out:
# Lexical richness of **text3** is 0.06230453042623537

# %% [markdown]
# - Higher the number of distinct words in given text, higher the lexical richness will be.
# - From above lexical richness is  0.062, i.e number of distinct words is just 6% of the total number of words.

# %% [markdown]
# Now let's define fuction named **lexical_diversity()** to calculate **lexical richness** of text

# %%
def lexical_diversity(text):
    '''
    calculates lexical richness of text
    
    Arguments:
    text: text whose lexical richness to be calculated
    
    Returns:
    lexical_richness: calculates lexical_richness of  text
    '''
    lexical_richness = len(set(text))/len(text)
    return lexical_richness

# %% [markdown]
# **4.word count in text**
# - counting number of times the given word occur in the given text

# %%
#count word "smote" in text3
smote_count = text3.count("smote")
print(f"The word 'smote' occured {smote_count} times in 'text3'")

#percentage of "text5" taken by the word "lol"
percent_lol_in_text5 = text5.count("lol")/len(text5)
print(f"\npercentage of word 'lol' in 'text5' is {percent_lol_in_text5}")
# Out:
# The word 'smote' occured 5 times in 'text3'
#
# percentage of word 'lol' in 'text5' is 0.015640968673628082

# %% [markdown]
# # Text as Lists of Words
#     In context of NLP Text is nothing more than a sequence of words and punctuation.

# %% [markdown]
# **1.Lists and basic operation with list**
# - Understanding what lists are and how to define it
# - Understanding operation assosciated with lists such as indexing and all.
#
# For this purpose, lets use sentence which is list of words and punctuation provided under nltk book module,
# - i.e. sent1, sent2, sent3....sent9

# %%
#define list
sentence_1  = ['call', 'me', 'Ishmael', '.']
sentence_1
# Out:
# ['call', 'me', 'Ishmael', '.']

# %%
#calculate lexical richness 
print(f"lexical richness is: {lexical_diversity(sentence_1)}")
# Out:
# lexical richness is: 1.0

# %%
#some basic operations
ex1 = ['Monty', 'Python', 'and', 'the', 'Holy', 'Grail']

#sort list, ascending
print(sorted(ex1))

#find length of distinct items of list
print(len(set(ex1)))

#count the word **the** in list 
print(ex1.count('the'))

#adding two lists
print(sent1+sent2)

#appendind item to list
print(f"\nlist before appending items:{sent1}")
sent1.append("Added")
print(f"\nlist after appending items:{sent1}")
# Out:
# ['Grail', 'Holy', 'Monty', 'Python', 'and', 'the']
# 6
# 1
# ['Call', 'me', 'Ishmael', '.', 'The', 'family', 'of', 'Dashwood', 'had', 'long', 'been', 'settled', 'in', 'Sussex', '.']
#
# list before appending items:['Call', 'me', 'Ishmael', '.']
#
# list after appending items:['Call', 'me', 'Ishmael', '.', 'Added']

# %% [markdown]
# **Indexing lists**
# - Indexes are common way to access the words of text, generally, the elements of any text
# - Extracting list items with the help of index assosciated with those items in lists

# %%
#extract item with index 173 from text4
print(f"item with index 173 from text4 is: {text4[173]}")

#find index of word "awaken" from text4
print(f"index of word 'awaken' from text4 is: {text4.index('awaken')}")
# Out:
# item with index 173 from text4 is: awaken
# index of word 'awaken' from text4 is: 173

# %% [markdown]
# **slicing lists**
# - Python permits us to access sublists as well.
# - Extracting manageable pieces of language from large texts, a technique known as slicing
# - Visit for more:
#     https://www.pythoncentral.io/how-to-slice-listsarrays-and-tuples-in-python/

# %%
#slicing text5

#slicing with start and end index
print(text5[100:110])

#slicing with only end index
print(text5[:3])

#slicing with only start index
# print(text5[10000:])

#slicing with negative index
print(text5[-3:]) #starting from 3rd index from last will print further
# Out:
# ['my', 'cousin', 'drew', 'a', 'messed', 'up', 'pic', 'on', 'my', 'cast']
# ['now', 'im', 'left']
# ['U98', 'Uh', '.']

# %% [markdown]
# **2.String and Basic operation**
# - Some methods used with list also work with individual words, or strings.
# - index string, slice string are possible as in list
# - visit for more:https://www.w3schools.com/python/python_strings.asp

# %%
#basic operation
name = 'Monty'

#access first character
print(name[0])

#slice upto 4 character
print(name[:4])
# Out:
# M
# Mont

# %%
#multiplication with strings
print(f"Multiplication with strings: {name*2}")

#addition with strings
string_add = name+'!'
print(f"Addition with strings: {string_add}")
# Out:
# Multiplication with strings: MontyMonty
# Addition with strings: Monty!

# %%
#join words of list to make single string
sample_list = ['Monty', 'Python']
print("join list to string:", ' '.join(sample_list)) #join by space

#Split string to list
sample_string = "Monty Python"
print("split string to list:", sample_string.split()) #split string by white space
# Out:
# join list to string: Monty Python
# split string to list: ['Monty', 'Python']

# %% [markdown]
# # Frequency Distribution From Text
# - **Q. How can we automatically identify the words of a text that are most informative about the topic and genre?
# - Frequency Distribution tells us the frequency of each vocabulary item in the text.
# - It is a "distribution" because it tells us how the total number of word tokens in the text are distributed across the vocabulary items.
# - Frequency Distribution is often needed in language processing, NLTK provides built-in support for them
# - Let's see **FreqDist**,

# %%
#Extracting frequency distribution from text
fdist = FreqDist(text1)
# Out:
# <FreqDist with 19317 samples and 260819 outcomes>

# %%
#extract frequency distribution of word "that"
fdist["that"]
# Out:
# 2982

# %%
#find number of unique word in given text or corpus
len(fdist)
# Out:
# 19317

# %%
#find most common words in given text
fdist.most_common(50) #50 most common words in text1
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624)]

# %% [markdown]
# - From above list  we can see 50 most common words in text
# - Most frequent word from above list doesnot gives much sense about, what text is  all about, as we can see there is only one word **whale** which gives sense i.e. it is slightly informative compared to others.
#
# Now, let's plot cummulative frequency for most common 50 words

# %%
#cummulative frequency plot for most common 50 words
fdist.plot(10, cumulative=True)
plt.show()

# %% [markdown]
# From above we can see that, around 75000 times these words appear in the book, which is nearly half of the book

# %% [markdown]
# **hapaxes (unique)**
# - Gives us the rare words in the given text.
# - As we see from above, frequent words doesnot gives genre, or what the text or book is about

# %%
#list infrequent words in given text
fdist.hapaxes()
# Out:
# ['Herman',
#  'Melville',
#  ']',
#  'ETYMOLOGY',
#  'Late',
#  'Consumptive',
#  'School',
#  'threadbare',
#  'lexicons',
#  'mockingly',
#  'flags',
#  'mortality',
#  'signification',
#  'HACKLUYT',
#  'Sw',
#  'HVAL',
#  'roundness',
#  'Dut',
#  'Ger',
#  'WALLEN',
#  'WALW',
#  'IAN',
#  'RICHARDSON',
#  'KETOS',
#  'GREEK',
#  'CETUS',
#  'LATIN',
#  'WHOEL',
#  'ANGLO',
#  'SAXON',
#  'WAL',
#  'HWAL',
#  'SWEDISH',
#  'ICELANDIC',
#  'BALEINE',
#  'BALLENA',
#  'FEGEE',
#  'ERROMANGOAN',
#  'Librarian',
#  'painstaking',
#  'burrower',
#  'grub',
#  'Vaticans',
#  'stalls',
#  'higgledy',
#  'piggledy',
#  'gospel',
#  'promiscuously',
#  'commentator',
#  'belongest',
#  'sallow',
#  'Pale',
#  'Sherry',
#  'loves',
#  'bluntly',
#  'Subs',
#  'thankless',
#  'Hampton',
#  'Court',
#  'hie',
#  'refugees',
#  'pampered',
#  'Michael',
#  'Raphael',
#  'unsplinterable',
#  'GENESIS',
#  'JOB',
#  'JONAH',
#  'punish',
#  'ISAIAH',
#  'soever',
#  'cometh',
# ...

# %% [markdown]
# Also, from above infrequent word, it is difficult to find what the genre or meaning of the given text as they are too many infrequent word.
#
# Since neither frequent nor infrequent words help to find genre or meaning of given text, need to try something else.

# %% [markdown]
# # Fine-Grained Selection of Words
# - previously, frequent words and infrequent words was failed to give proper meaning of text.
# - lets, take a look at the long words of a text; perhaps these will be more characteristic and informative.
# - For this, let's find the word of vocabulary of the text that are more than 15 characters long.

# %%
#extracting unique words of length greater than 15, from text1
unique_words = set(text1)
long_words = [word for word in unique_words if len(word)>15]
sorted(long_words)
# Out:
# ['CIRCUMNAVIGATION',
#  'Physiognomically',
#  'apprehensiveness',
#  'cannibalistically',
#  'characteristically',
#  'circumnavigating',
#  'circumnavigation',
#  'circumnavigations',
#  'comprehensiveness',
#  'hermaphroditical',
#  'indiscriminately',
#  'indispensableness',
#  'irresistibleness',
#  'physiognomically',
#  'preternaturalness',
#  'responsibilities',
#  'simultaneousness',
#  'subterraneousness',
#  'supernaturalness',
#  'superstitiousness',
#  'uncomfortableness',
#  'uncompromisedness',
#  'undiscriminating',
#  'uninterpenetratingly']

# %% [markdown]
# Successfully, extracted words that are longer than size 15
# Now, it will be very informative, if we extract most frequent words that are long enough, lets do that,

# %%
#extract words from text1 that is most frequent and long(length>=9)
fdist1 = FreqDist(text1)
frequent_long_words = sorted(word for word in set(text1) if (fdist1[word]>=9 and len(word)>=9))
frequent_long_words
# Out:
# ['Christian',
#  'Commodore',
#  'Greenland',
#  'Leviathan',
#  'Meanwhile',
#  'Mediterranean',
#  'NANTUCKET',
#  'Nantucket',
#  'Nantucketer',
#  'Nantucketers',
#  'Nevertheless',
#  'Sebastian',
#  'Steelkilt',
#  'Therefore',
#  'abounding',
#  'according',
#  'accounted',
#  'additional',
#  'advancing',
#  'afternoon',
#  'afterwards',
#  'alongside',
#  'altogether',
#  'ambergris',
#  'appalling',
#  'apparently',
#  'apparition',
#  'appearance',
#  'approaching',
#  'attention',
#  'beginning',
#  'beholding',
#  'blackness',
#  'blacksmith',
#  'breakfast',
#  'cannibals',
#  'carefully',
#  'carpenter',
#  'centuries',
#  'certainly',
#  'character',
#  'circumstance',
#  'circumstances',
#  'civilized',
#  'comfortable',
#  'commanded',
#  'commander',
#  'commotion',
#  'compasses',
#  'completely',
#  'concerning',
#  'concluded',
#  'concluding',
#  'confidential',
#  'connected',
#  'conscience',
#  'considerable',
#  'considerably',
#  'considered',
# ...

# %% [markdown]
# - Above list of words gives little more meaning assosciated with the text1.
# - Hence, managed to automatically identify the frequently-occurring content-bearing words of the text.
# - It is small but gives valuable insights, processing large number of words, giving some informative output.

# %% [markdown]
# # Collocations and Bigrams
# - A **collocation** is a sequence of words that occur together unsually often,  Thus _red wine_ is a collocation, whereas _the wine_ is not.
# - Also, **collocations** are phrases or expressions that are highly likely to co-occur
# - We extract frequently together words from the text
# - Example: good film, las vegas, new york and so-on
# - Visit for more:
#     - https://towardsdatascience.com/collocations-in-nlp-using-nltk-library-2541002998db
#     - https://www.nltk.org/howto/collocations.html

# %% [markdown]
# **How collocations different from Bigrams**
# - Bigrams means the set of two words(e.g. this is, red wine, is said and so-on) that co-occur, while trigrams means set of three words that co-occur
# - Bigrams or Trigrams may not give us meaning phrases.
# - Example:
#     - consider sentence: "He applied machine learning" contains biagrams i.e.
#     - Biagrams: 'He applied', 'applied machine', 'machine learning'.
#     - 'He applied' and 'applied machine' is not meaningful, while 'machine learning' is a meaningful biagrams.
# - Thus, just considering co-occurring words may not be a good idea, since phrases such as 'of the' may occur frequently, but are actually not meaningful
# - Thus the need for collocations from NLTK library. It only gives us the meaningful bigrams and trigrams
#
# **How one collocation better than other?**
# - Pointwise Mutual Information or PMI score is used.
# - PMI scores is used to rank the bigrams and trigrams churned out by collocations library.
#     - PMI(a, b) = log( p(a, b)/(p(a) * p(b)) )
#
# Now, for demo purpose let's extract list of bigrams from text1,

# %%
#extract bigrams from text1
list(bigrams(text1))
# Out:
# [('[', 'Moby'),
#  ('Moby', 'Dick'),
#  ('Dick', 'by'),
#  ('by', 'Herman'),
#  ('Herman', 'Melville'),
#  ('Melville', '1851'),
#  ('1851', ']'),
#  (']', 'ETYMOLOGY'),
#  ('ETYMOLOGY', '.'),
#  ('.', '('),
#  ('(', 'Supplied'),
#  ('Supplied', 'by'),
#  ('by', 'a'),
#  ('a', 'Late'),
#  ('Late', 'Consumptive'),
#  ('Consumptive', 'Usher'),
#  ('Usher', 'to'),
#  ('to', 'a'),
#  ('a', 'Grammar'),
#  ('Grammar', 'School'),
#  ('School', ')'),
#  (')', 'The'),
#  ('The', 'pale'),
#  ('pale', 'Usher'),
#  ('Usher', '--'),
#  ('--', 'threadbare'),
#  ('threadbare', 'in'),
#  ('in', 'coat'),
#  ('coat', ','),
#  (',', 'heart'),
#  ('heart', ','),
#  (',', 'body'),
#  ('body', ','),
#  (',', 'and'),
#  ('and', 'brain'),
#  ('brain', ';'),
#  (';', 'I'),
#  ('I', 'see'),
#  ('see', 'him'),
#  ('him', 'now'),
#  ('now', '.'),
#  ('.', 'He'),
#  ('He', 'was'),
#  ('was', 'ever'),
#  ('ever', 'dusting'),
#  ('dusting', 'his'),
#  ('his', 'old'),
#  ('old', 'lexicons'),
# ...

# %%
#extract collocations from text1
text4.collocation_list()
# Out:
# ['United States',
#  'fellow citizens',
#  'four years',
#  'years ago',
#  'Federal Government',
#  'General Government',
#  'American people',
#  'Vice President',
#  'God bless',
#  'Chief Justice',
#  'Old World',
#  'Almighty God',
#  'Fellow citizens',
#  'Chief Magistrate',
#  'every citizen',
#  'one another',
#  'fellow Americans',
#  'Indian tribes',
#  'public debt',
#  'foreign nations']

# %% [markdown]
# # Counting Other Things Than Words
# - Counting words is useful, but we can count other things too.
# - Example: We can look at the distribution of word lengths in text, shown below,

# %%
#Distribution of word lengths in text1  

#make list of length of all words
word_length_list = [len(word) for word in text1]

#generate frequency distribution using FreqDist
fdist = FreqDist(word_length_list)
print(fdist)

#show frequency  distribution
fdist
# Out:
# <FreqDist with 19 samples and 260819 outcomes>
# FreqDist({3: 50223, 1: 47933, 4: 42345, 2: 38513, 5: 26597, 6: 17111, 7: 14399, 8: 9966, 9: 6428, 10: 3528, ...})

# %% [markdown]
# Also, plot frequency distribution of length of words from text1

# %%
#plot frequency distribution
fdist.plot(20, cumulative=False)
plt.show()

# %% [markdown]
# - As we can see from above, **text1** contains **maximum words** with **length=3**
# - Whereas, **text1** contains **minimum words** with **length=3**

# %%
#find most common
fdist.most_common()
# Out:
# [(3, 50223),
#  (1, 47933),
#  (4, 42345),
#  (2, 38513),
#  (5, 26597),
#  (6, 17111),
#  (7, 14399),
#  (8, 9966),
#  (9, 6428),
#  (10, 3528),
#  (11, 1873),
#  (12, 1053),
#  (13, 567),
#  (14, 177),
#  (15, 70),
#  (16, 22),
#  (17, 12),
#  (18, 1),
#  (20, 1)]

# %%
#find word length whose count is maximum
fdist.max()
# Out:
# 3

# %% [markdown]
# **Q. what % of word in text1 is of length 3**

# %%
#%word of length 3
print("The % of word in text1 of length 3 is:", fdist.freq(3))
# Out:
# The % of word in text1 of length 3 is: 0.19255882431878046

# %% [markdown]
# From above we can see that around 20% of text contains word of length 3.
# **Frequency Distribution Summary:**
# ![frequency distribution summary](frequency_distribution_summary.png)

# %% [markdown]
# # Making Decisions and Taking Control
# - A key feature of programming is the ability of machines to make decisions on our behalf such as:
#     - Executing instruction when certain conditions are met,
#     - Repeatedly looping through text data until some condition is satisfied.
#
# - This feature is called **control**
#
# **1.Conditionals**

# %% [markdown]
# **Numerical Comparison Operators**
# - Python supports a wide range of operators, such as < and >=, for testing the relationship between values
# - The full set of these relational operators is shown
#     - <	less than
#     - <=	less than or equal to
#     - ==	equal to (note this is two "=" signs, not one)
#     - !=	not equal to
#     - greater than
#     - greater than or equal to
# - Demonstration is as shown below,

# %%
#less than
print([w for w in sent7 if len(w) < 4])

#less than or equal to
print([w for w in sent7 if len(w) <= 4])

#equal to
print([w for w in sent7 if len(w) == 4])  

#not equal to
print([w for w in sent7 if len(w) != 4])
# Out:
# [',', '61', 'old', ',', 'the', 'as', 'a', '29', '.']
# [',', '61', 'old', ',', 'will', 'join', 'the', 'as', 'a', 'Nov.', '29', '.']
# ['will', 'join', 'Nov.']
# ['Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'the', 'board', 'as', 'a', 'nonexecutive', 'director', '29', '.']

# %% [markdown]
# **Word comparison operators**
# - Helps to select words from our texts.
# - Some word comparisons operators are listed below
#     - **s.startswith(t):**	test if s starts with t
#     - **s.endswith(t):**	test if s ends with t
#     - **t in s:**	test if t is a substring of s
#     - **s.islower():**	test if s contains cased characters and all are lowercase
#     - **s.isupper():**	test if s contains cased characters and all are uppercase
#     - **s.isalpha():**	test if s is non-empty and all characters in s are alphabetic
#     - **s.isalnum():**	test if s is non-empty and all characters in s are alphanumeric
#     - **s.isdigit():**	test if s is non-empty and all characters in s are digits
#     - **s.istitle():**	test if s contains cased characters and is titlecased (i.e. all words in s have initial capitals)
# - Demonstration using above is as shown,

# %%
#list of words ending with -ableness- from Text1
print(sorted(w for w in set(text1) if w.endswith('ableness')))
# Out:
# ['comfortableness',
#  'honourableness',
#  'immutableness',
#  'indispensableness',
#  'indomitableness',
#  'intolerableness',
#  'palpableness',
#  'reasonableness',
#  'uncomfortableness']

# %%
#list of words containing -gnt-
print(sorted(term for term in set(text4) if 'gnt' in term))
# Out:
# ['Sovereignty', 'sovereignties', 'sovereignty']

# %%
#list of words having an initial capital
print(sorted(item for item in set(text6) if item.istitle()))
# Out:
# ['A', 'Aaaaaaaaah', 'Aaaaaaaah', 'Aaaaaah', 'Aaaah', 'Aaaaugh', 'Aaagh', 'Aaah', 'Aaauggh', 'Aaaugh', 'Aaauugh', 'Aagh', 'Aah', 'Aauuggghhh', 'Aauuugh', 'Aauuuuugh', 'Aauuuves', 'Action', 'Actually', 'African', 'Ages', 'Aggh', 'Agh', 'Ah', 'Ahh', 'Alice', 'All', 'Allo', 'Almighty', 'Alright', 'Am', 'Amen', 'An', 'Anarcho', 'And', 'Angnor', 'Anthrax', 'Antioch', 'Anybody', 'Anyway', 'Apples', 'Aramaic', 'Are', 'Arimathea', 'Armaments', 'Arthur', 'As', 'Ask', 'Assyria', 'At', 'Attila', 'Augh', 'Autumn', 'Auuuuuuuugh', 'Away', 'Ay', 'Ayy', 'B', 'Back', 'Bad', 'Badon', 'Battle', 'Be', 'Beast', 'Bedevere', 'Bedwere', 'Behold', 'Between', 'Beyond', 'Black', 'Bloody', 'Blue', 'Bon', 'Bones', 'Book', 'Bors', 'Brave', 'Bravely', 'Bravest', 'Bread', 'Bridge', 'Bring', 'Bristol', 'Britain', 'Britons', 'Brother', 'Build', 'Burn', 'But', 'By', 'C', 'Caerbannog', 'Camaaaaaargue', 'Camelot', 'Castle', 'Chapter', 'Charge', 'Chaste', 'Cherries', 'Chicken', 'Chickennn', 'Chop', 'Christ', 'Churches', '
# ...

# %%
#list of words consisting entirely of digits
print(sorted(item for item in set(sent7) if item.isdigit()))
# Out:
# ['29', '61']

# %% [markdown]
# Also, we can combne two or more conditions to form a new condition using conjunction and disjunction: c1 and c2, c1 or c2 as,

# %%
#combining two or more conditions
print(sorted(w for w in set(text7) if '-' in w and 'index' in w))
print('\n', sorted(wd for wd in set(text3) if wd.istitle() and len(wd) > 10))
print('\n', sorted(w for w in set(sent7) if not w.islower()))
print('\n', sorted(t for t in set(text2) if 'cie' in t or 'cei' in t))
# Out:
# ['Stock-index', 'index-arbitrage', 'index-fund', 'index-options', 'index-related', 'stock-index']
#
#  ['Abelmizraim', 'Allonbachuth', 'Beerlahairoi', 'Canaanitish', 'Chedorlaomer', 'Girgashites', 'Hazarmaveth', 'Hazezontamar', 'Ishmeelites', 'Jegarsahadutha', 'Jehovahjireh', 'Kirjatharba', 'Melchizedek', 'Mesopotamia', 'Peradventure', 'Philistines', 'Zaphnathpaaneah']
#
#  [',', '.', '29', '61', 'Nov.', 'Pierre', 'Vinken']
#
#  ['ancient', 'ceiling', 'conceit', 'conceited', 'conceive', 'conscience', 'conscientious', 'conscientiously', 'deceitful', 'deceive', 'deceived', 'deceiving', 'deficiencies', 'deficiency', 'deficient', 'delicacies', 'excellencies', 'fancied', 'insufficiency', 'insufficient', 'legacies', 'perceive', 'perceived', 'perceiving', 'prescience', 'prophecies', 'receipt', 'receive', 'received', 'receiving', 'society', 'species', 'sufficient', 'sufficiently', 'undeceive', 'undeceiving']
